# %%
1. Why are functions advantageous to have in your programs?
Answer:- Code reability & code resuability

# %%
2. When does the code in a function run: when it's specified or when it's called?
Answer:-function run when it is called

# %%
3. What statement creates a function?
Answer:- def function_name():
this line create function

# %%
4. What is the difference between a function and a function call?
Answer:-
Function is where the code of the function block is written while function call is used to call the function block

# %%
5. How many global scopes are there in a Python program? How many local scopes?
Answer:-
There is only 1 global scope in Python Program.
Whenever a function like block is created local scope is created too.

# %%
6. What happens to variables in a local scope when the function call returns?
Answer:-
Once the value is returned the memory occupied by local variable are released by garbage collector and local scope is erased.

# %%
7. What is the concept of a return value? Is it possible to have a return value in an expression?
Answer:- Suppose after executions of all statements inside functions we arrived at some value which need to be sent to function call for further calculation in such scenarios we use return keyword to send that data to function call.
Yes,we can use return value in an expression.

# %%
8. If a function does not have a return statement, what is the return value of a call to that function?
Answer:-In such cases function return None to function call.

# %%
9. How do you make a function variable refer to the global variable?
Answer:- We can use global keyword to refer to the global variable.This will make that variable at global scope.

# %%
10. What is the data type of None?
Answer:-It's data type is NoneType

# %%
11. What does the sentence import areallyourpetsnamederic do?
Answer:- It will import the areallyourpetsnamederic module in your code.

# %%
12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
Answer:- spam.bacon()

# %%
13. What can you do to save a programme from crashing if it encounters an error?
Answer:-We can use try-except block(exception handling) to overcome this error

# %%
14. What is the purpose of the try clause? What is the purpose of the except clause?
Answer:- try block is used to capture the exception if found and pass it it except block.
except block is used to handle the error sent from try block correctly.
