# %%
1. To what does a relative path refer?
Answer:-It refers to location of a file or folder, relative to the current working directory.

# %%
2. What does an absolute path start with your operating system?
Answer:- It's start with the drive name(C,D,E etc)

# %%
3. What do the functions os.getcwd() and os.chdir() do?
Answer:-
os.getcwd()-To check the current directory of the code execution
os.chdir()-To change the current directory of the code execution.

# %%
4. What are the . and .. folders?
Answer:- . is shortform of this dirtectory while .. means the parent folder

# %%
5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?
Answer:-
dir name:- C:\bacon\eggs
base name:- spam.txt

# %%
6. What are the three “mode” arguments that can be passed to the open() function?
Answer:- 
Read mode - "r"
Write mode - "w"
Append mode - "a"

# %%
7. What happens if an existing file is opened in write mode?
Answer:-
When you open a file for writing, if the file exists, the existing file is overwritten with the new file.

# %%
8. How do you tell the difference between read() and readlines()?
Answer:-
read return you the whole text as it is while readlines() returns list of lines of text.

# %%
9. What data structure does a shelf value resemble?
Answer:- It resembles dictionary.
